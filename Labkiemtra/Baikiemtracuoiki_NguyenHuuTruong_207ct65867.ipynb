# %% [markdown]
# # Đề kiểm tra lập trình nhập môn phân tích dữ liệu và học sâu

# %% [markdown]
# ### Sinh viên không được phép sử dụng internet
# ### Sinh viên sau khi làm bài xong xuất ra file PDF đồng thời nộp lên Fit-lab và push lên git-hub
# ### Sinh viên làm bắt đầu làm bài từ 15h40 - 18h00

# %%
# Họ và Tên: Nguyễn Hữu Trường
# MSSV: 207CT65867

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
#Bước 1: Load data
def load_dataset():
    X, y = load_iris(return_X_y=True)
    X = X[y!=2]
    y = y[y!=2]
    return X,y
#Điền ở đây
X,y = load_dataset()
print(X.shape,y.shape)
# Out:
# (100, 4) (100,)

# %% [markdown]
# Kết quả: (100, 4) (100,)

# %%
#Trực quan hóa dữ liệu data
#Điền code ở đây
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
# Bước 2: Định nghĩa mô hình hồi quy logistic bằng PyTorch
class LogisticRegressTorch(nn.Module):
    def __init__(self, n_features):
        super(LogisticRegressTorch, self).__init__()
        #Điền ở đây theo comment                # tạo một lớp tuyến tính (nn.Linear) với n_features đầu vào và 1 đầu ra
        self.linear = nn.Linear(n_features, 1)
    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
# Bước 3: Định nghĩa lớp dữ liệu
class IrisTorch(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)

    def __len__(self):
        return len(self.X) #Điền ở đây theo comment            #trả về số lượng mẫu trong tập dữ liệu (số lượng hàng trong self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]  #Điền ở đây theo comment            #trả về một cặp đặc trưng và nhãn tương ứng với chỉ số idx

# %%
# Tạo dữ liệu
dataset = IrisTorch(X, y)

# %%
# Bước 4: Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra bằng cách chia ngẫu nhiên 70,30.
train_size = int(0.7 * len(dataset))               #70%
test_size =  test_size = len(dataset) - train_size #30%
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Tạo DataLoader
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Bước 5: Định nghĩa criterion và optimizer
n_features = X.shape[1]
model = LogisticRegressTorch(n_features)
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.04)

# %%
# Huấn luyện mô hình
n_epochs = 200
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(n_epochs):
    model.train()
    train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)

    # Đánh giá trên tập kiểm tra
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item() * inputs.size(0)

            predicted = (outputs >= 0.5).float()
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)

    accuracy = correct / total
    test_accuracies.append(accuracy)

    print(f'Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/200, Train Loss: 1.2185, Test Loss: 0.6513, Test Accuracy: 0.5667
# Epoch 2/200, Train Loss: 0.7348, Test Loss: 0.5430, Test Accuracy: 0.7667
# Epoch 3/200, Train Loss: 0.5668, Test Loss: 0.5393, Test Accuracy: 0.9667
# Epoch 4/200, Train Loss: 0.5385, Test Loss: 0.5003, Test Accuracy: 0.5667
# Epoch 5/200, Train Loss: 0.5481, Test Loss: 0.4920, Test Accuracy: 0.5667
# Epoch 6/200, Train Loss: 0.5409, Test Loss: 0.4544, Test Accuracy: 0.9667
# Epoch 7/200, Train Loss: 0.4778, Test Loss: 0.4363, Test Accuracy: 0.9667
# Epoch 8/200, Train Loss: 0.4602, Test Loss: 0.4338, Test Accuracy: 1.0000
# Epoch 9/200, Train Loss: 0.4317, Test Loss: 0.4018, Test Accuracy: 1.0000
# Epoch 10/200, Train Loss: 0.4188, Test Loss: 0.3895, Test Accuracy: 1.0000
# Epoch 11/200, Train Loss: 0.3982, Test Loss: 0.3759, Test Accuracy: 1.0000
# Epoch 12/200, Train Loss: 0.3832, Test Loss: 0.3730, Test Accuracy: 1.0000
# Epoch 13/200, Train Loss: 0.3693, Test Loss: 0.3467, Test Accuracy: 1.0000
# Epoch 14/200, Train Loss: 0.3573, Test Loss: 0.3432, Test Accuracy: 1.0000
# Epoch 15/200, Train Loss: 0.3429, Test Loss: 0.3422, Test Accuracy: 1.0000
# Epoch 16/200, Train Loss: 0.3336, Test Loss: 0.3200, Test Accuracy: 1.0000
# Epoch 17/200, Train Loss: 0.3196, Test Loss: 0.3085, Test Accuracy: 1.0000
# Epoch 18/200, Train Loss: 0.3092, Test Loss: 0.2985, Test Accuracy: 1.0000
# Epoch 19/200, Train Loss: 0.2998, Test Loss: 0.2981, Test Accuracy: 1.0000
# Epoch 20/200, Train Loss: 0.2922, Test Loss: 0.2900, Test Accuracy: 1.0000
# Epoch 21/200, Train Loss: 0.2845, Test Loss: 0.3000, Test Accuracy: 1.0000
# Epoch 22/200, Train Loss: 0.2839, Test Loss: 0.2810, Test Accuracy: 1.0000
# Epoch 23/200, Train Loss: 0.2706, Test Loss: 0.2738, Test Accuracy: 1.0000
# Epoch 24/200, Train Loss: 0.2622, Test Loss: 0.2514, Test Accuracy: 1.0000
# Epoch 25/200, Train Loss: 0.2513, Test Loss: 0.2492, Test Accuracy: 1.0000
# Epoch 26/200, Train Loss: 0.2455, Test Loss: 0.2602, Test Accuracy: 1.0000
# Epoch 27/200, Train Loss: 0.2459, Test Loss: 0.2499, Test Accuracy: 1.0000
# Epoch 28/200, Train Loss: 0.2377, Test Loss: 0.2438, Test Accuracy: 1.0000
# Epoch 29/200, Train Loss: 0.2322, Test Loss: 0.2452, Test Accuracy: 1.0000
# Epoch 30/200, Train Loss: 0.2295, Test Loss: 0.2314, Test Accuracy: 1.0000
# Epoch 31/200, Train Loss: 0.2200, Test Loss: 0.2277, Test Accuracy: 1.0000
# Epoch 32/200, Train Loss: 0.2155, Test Loss: 0.2231, Test Accuracy: 1.0000
# Epoch 33/200, Train Loss: 0.2102, Test Loss: 0.2093, Test Accuracy: 1.0000
# Epoch 34/200, Train Loss: 0.2017, Test Loss: 0.2012, Test Accuracy: 1.0000
# Epoch 35/200, Train Loss: 0.1964, Test Loss: 0.1946, Test Accuracy: 1.0000
# Epoch 36/200, Train Loss: 0.1920, Test Loss: 0.1896, Test Accuracy: 1.0000
# Epoch 37/200, Train Loss: 0.1882, Test Loss: 0.1849, Test Accuracy: 1.0000
# Epoch 38/200, Train Loss: 0.1851, Test Loss: 0.1804, Test Accuracy: 1.0000
# Epoch 39/200, Train Loss: 0.1831, Test Loss: 0.1770, Test Accuracy: 1.0000
# Epoch 40/200, Train Loss: 0.1793, Test Loss: 0.1750, Test Accuracy: 1.0000
# Epoch 41/200, Train Loss: 0.1743, Test Loss: 0.1706, Test Accuracy: 1.0000
# Epoch 42/200, Train Loss: 0.1735, Test Loss: 0.1683, Test Accuracy: 1.0000
# Epoch 43/200, Train Loss: 0.1683, Test Loss: 0.1651, Test Accuracy: 1.0000
# Epoch 44/200, Train Loss: 0.1657, Test Loss: 0.1622, Test Accuracy: 1.0000
# Epoch 45/200, Train Loss: 0.1628, Test Loss: 0.1596, Test Accuracy: 1.0000
# Epoch 46/200, Train Loss: 0.1591, Test Loss: 0.1603, Test Accuracy: 1.0000
# Epoch 47/200, Train Loss: 0.1553, Test Loss: 0.1568, Test Accuracy: 1.0000
# Epoch 48/200, Train Loss: 0.1525, Test Loss: 0.1543, Test Accuracy: 1.0000
# Epoch 49/200, Train Loss: 0.1499, Test Loss: 0.1541, Test Accuracy: 1.0000
# Epoch 50/200, Train Loss: 0.1475, Test Loss: 0.1475, Test Accuracy: 1.0000
# Epoch 51/200, Train Loss: 0.1453, Test Loss: 0.1446, Test Accuracy: 1.0000
# Epoch 52/200, Train Loss: 0.1435, Test Loss: 0.1420, Test Accuracy: 1.0000
# Epoch 53/200, Train Loss: 0.1426, Test Loss: 0.1400, Test Accuracy: 1.0000
# Epoch 54/200, Train Loss: 0.1400, Test Loss: 0.1380, Test Accuracy: 1.0000
# Epoch 55/200, Train Loss: 0.1372, Test Loss: 0.1379, Test Accuracy: 1.0000
# Epoch 56/200, Train Loss: 0.1340, Test Loss: 0.1358, Test Accuracy: 1.0000
# Epoch 57/200, Train Loss: 0.1318, Test Loss: 0.1348, Test Accuracy: 1.0000
# Epoch 58/200, Train Loss: 0.1299, Test Loss: 0.1298, Test Accuracy: 1.0000
# Epoch 59/200, Train Loss: 0.1301, Test Loss: 0.1287, Test Accuracy: 1.0000
# Epoch 60/200, Train Loss: 0.1268, Test Loss: 0.1270, Test Accuracy: 1.0000
# Epoch 61/200, Train Loss: 0.1247, Test Loss: 0.1271, Test Accuracy: 1.0000
# Epoch 62/200, Train Loss: 0.1223, Test Loss: 0.1252, Test Accuracy: 1.0000
# Epoch 63/200, Train Loss: 0.1207, Test Loss: 0.1234, Test Accuracy: 1.0000
# Epoch 64/200, Train Loss: 0.1191, Test Loss: 0.1211, Test Accuracy: 1.0000
# Epoch 65/200, Train Loss: 0.1178, Test Loss: 0.1202, Test Accuracy: 1.0000
# Epoch 66/200, Train Loss: 0.1161, Test Loss: 0.1180, Test Accuracy: 1.0000
# Epoch 67/200, Train Loss: 0.1147, Test Loss: 0.1187, Test Accuracy: 1.0000
# Epoch 68/200, Train Loss: 0.1130, Test Loss: 0.1151, Test Accuracy: 1.0000
# Epoch 69/200, Train Loss: 0.1119, Test Loss: 0.1132, Test Accuracy: 1.0000
# Epoch 70/200, Train Loss: 0.1111, Test Loss: 0.1116, Test Accuracy: 1.0000
# Epoch 71/200, Train Loss: 0.1103, Test Loss: 0.1113, Test Accuracy: 1.0000
# Epoch 72/200, Train Loss: 0.1078, Test Loss: 0.1096, Test Accuracy: 1.0000
# Epoch 73/200, Train Loss: 0.1067, Test Loss: 0.1080, Test Accuracy: 1.0000
# Epoch 74/200, Train Loss: 0.1058, Test Loss: 0.1065, Test Accuracy: 1.0000
# Epoch 75/200, Train Loss: 0.1050, Test Loss: 0.1054, Test Accuracy: 1.0000
# Epoch 76/200, Train Loss: 0.1037, Test Loss: 0.1042, Test Accuracy: 1.0000
# Epoch 77/200, Train Loss: 0.1026, Test Loss: 0.1039, Test Accuracy: 1.0000
# Epoch 78/200, Train Loss: 0.1004, Test Loss: 0.1028, Test Accuracy: 1.0000
# Epoch 79/200, Train Loss: 0.0992, Test Loss: 0.1016, Test Accuracy: 1.0000
# Epoch 80/200, Train Loss: 0.0981, Test Loss: 0.1017, Test Accuracy: 1.0000
# Epoch 81/200, Train Loss: 0.0967, Test Loss: 0.1016, Test Accuracy: 1.0000
# Epoch 82/200, Train Loss: 0.0956, Test Loss: 0.1013, Test Accuracy: 1.0000
# Epoch 83/200, Train Loss: 0.0947, Test Loss: 0.1026, Test Accuracy: 1.0000
# Epoch 84/200, Train Loss: 0.0942, Test Loss: 0.0987, Test Accuracy: 1.0000
# Epoch 85/200, Train Loss: 0.0927, Test Loss: 0.0993, Test Accuracy: 1.0000
# Epoch 86/200, Train Loss: 0.0919, Test Loss: 0.0972, Test Accuracy: 1.0000
# Epoch 87/200, Train Loss: 0.0908, Test Loss: 0.0976, Test Accuracy: 1.0000
# Epoch 88/200, Train Loss: 0.0901, Test Loss: 0.0976, Test Accuracy: 1.0000
# Epoch 89/200, Train Loss: 0.0894, Test Loss: 0.0940, Test Accuracy: 1.0000
# Epoch 90/200, Train Loss: 0.0880, Test Loss: 0.0917, Test Accuracy: 1.0000
# Epoch 91/200, Train Loss: 0.0872, Test Loss: 0.0913, Test Accuracy: 1.0000
# Epoch 92/200, Train Loss: 0.0863, Test Loss: 0.0906, Test Accuracy: 1.0000
# Epoch 93/200, Train Loss: 0.0855, Test Loss: 0.0909, Test Accuracy: 1.0000
# Epoch 94/200, Train Loss: 0.0846, Test Loss: 0.0893, Test Accuracy: 1.0000
# Epoch 95/200, Train Loss: 0.0837, Test Loss: 0.0893, Test Accuracy: 1.0000
# Epoch 96/200, Train Loss: 0.0831, Test Loss: 0.0862, Test Accuracy: 1.0000
# Epoch 97/200, Train Loss: 0.0826, Test Loss: 0.0853, Test Accuracy: 1.0000
# Epoch 98/200, Train Loss: 0.0820, Test Loss: 0.0841, Test Accuracy: 1.0000
# Epoch 99/200, Train Loss: 0.0820, Test Loss: 0.0836, Test Accuracy: 1.0000
# Epoch 100/200, Train Loss: 0.0807, Test Loss: 0.0829, Test Accuracy: 1.0000
# Epoch 101/200, Train Loss: 0.0799, Test Loss: 0.0829, Test Accuracy: 1.0000
# Epoch 102/200, Train Loss: 0.0786, Test Loss: 0.0817, Test Accuracy: 1.0000
# Epoch 103/200, Train Loss: 0.0782, Test Loss: 0.0812, Test Accuracy: 1.0000
# Epoch 104/200, Train Loss: 0.0775, Test Loss: 0.0804, Test Accuracy: 1.0000
# Epoch 105/200, Train Loss: 0.0769, Test Loss: 0.0807, Test Accuracy: 1.0000
# Epoch 106/200, Train Loss: 0.0758, Test Loss: 0.0802, Test Accuracy: 1.0000
# Epoch 107/200, Train Loss: 0.0751, Test Loss: 0.0795, Test Accuracy: 1.0000
# Epoch 108/200, Train Loss: 0.0745, Test Loss: 0.0789, Test Accuracy: 1.0000
# Epoch 109/200, Train Loss: 0.0739, Test Loss: 0.0779, Test Accuracy: 1.0000
# Epoch 110/200, Train Loss: 0.0733, Test Loss: 0.0781, Test Accuracy: 1.0000
# Epoch 111/200, Train Loss: 0.0726, Test Loss: 0.0782, Test Accuracy: 1.0000
# Epoch 112/200, Train Loss: 0.0721, Test Loss: 0.0782, Test Accuracy: 1.0000
# Epoch 113/200, Train Loss: 0.0716, Test Loss: 0.0782, Test Accuracy: 1.0000
# Epoch 114/200, Train Loss: 0.0711, Test Loss: 0.0784, Test Accuracy: 1.0000
# Epoch 115/200, Train Loss: 0.0707, Test Loss: 0.0767, Test Accuracy: 1.0000
# Epoch 116/200, Train Loss: 0.0699, Test Loss: 0.0764, Test Accuracy: 1.0000
# Epoch 117/200, Train Loss: 0.0695, Test Loss: 0.0759, Test Accuracy: 1.0000
# Epoch 118/200, Train Loss: 0.0689, Test Loss: 0.0757, Test Accuracy: 1.0000
# Epoch 119/200, Train Loss: 0.0685, Test Loss: 0.0752, Test Accuracy: 1.0000
# Epoch 120/200, Train Loss: 0.0680, Test Loss: 0.0734, Test Accuracy: 1.0000
# Epoch 121/200, Train Loss: 0.0672, Test Loss: 0.0719, Test Accuracy: 1.0000
# Epoch 122/200, Train Loss: 0.0667, Test Loss: 0.0711, Test Accuracy: 1.0000
# Epoch 123/200, Train Loss: 0.0662, Test Loss: 0.0719, Test Accuracy: 1.0000
# Epoch 124/200, Train Loss: 0.0657, Test Loss: 0.0705, Test Accuracy: 1.0000
# Epoch 125/200, Train Loss: 0.0652, Test Loss: 0.0703, Test Accuracy: 1.0000
# Epoch 126/200, Train Loss: 0.0647, Test Loss: 0.0706, Test Accuracy: 1.0000
# Epoch 127/200, Train Loss: 0.0642, Test Loss: 0.0708, Test Accuracy: 1.0000
# Epoch 128/200, Train Loss: 0.0639, Test Loss: 0.0710, Test Accuracy: 1.0000
# Epoch 129/200, Train Loss: 0.0635, Test Loss: 0.0691, Test Accuracy: 1.0000
# Epoch 130/200, Train Loss: 0.0628, Test Loss: 0.0678, Test Accuracy: 1.0000
# Epoch 131/200, Train Loss: 0.0623, Test Loss: 0.0672, Test Accuracy: 1.0000
# Epoch 132/200, Train Loss: 0.0619, Test Loss: 0.0677, Test Accuracy: 1.0000
# Epoch 133/200, Train Loss: 0.0615, Test Loss: 0.0672, Test Accuracy: 1.0000
# Epoch 134/200, Train Loss: 0.0610, Test Loss: 0.0656, Test Accuracy: 1.0000
# Epoch 135/200, Train Loss: 0.0606, Test Loss: 0.0651, Test Accuracy: 1.0000
# Epoch 136/200, Train Loss: 0.0602, Test Loss: 0.0639, Test Accuracy: 1.0000
# Epoch 137/200, Train Loss: 0.0600, Test Loss: 0.0637, Test Accuracy: 1.0000
# Epoch 138/200, Train Loss: 0.0595, Test Loss: 0.0639, Test Accuracy: 1.0000
# Epoch 139/200, Train Loss: 0.0590, Test Loss: 0.0632, Test Accuracy: 1.0000
# Epoch 140/200, Train Loss: 0.0587, Test Loss: 0.0626, Test Accuracy: 1.0000
# Epoch 141/200, Train Loss: 0.0584, Test Loss: 0.0626, Test Accuracy: 1.0000
# Epoch 142/200, Train Loss: 0.0578, Test Loss: 0.0630, Test Accuracy: 1.0000
# Epoch 143/200, Train Loss: 0.0573, Test Loss: 0.0622, Test Accuracy: 1.0000
# Epoch 144/200, Train Loss: 0.0569, Test Loss: 0.0630, Test Accuracy: 1.0000
# Epoch 145/200, Train Loss: 0.0566, Test Loss: 0.0622, Test Accuracy: 1.0000
# Epoch 146/200, Train Loss: 0.0562, Test Loss: 0.0609, Test Accuracy: 1.0000
# Epoch 147/200, Train Loss: 0.0558, Test Loss: 0.0605, Test Accuracy: 1.0000
# Epoch 148/200, Train Loss: 0.0555, Test Loss: 0.0602, Test Accuracy: 1.0000
# Epoch 149/200, Train Loss: 0.0552, Test Loss: 0.0601, Test Accuracy: 1.0000
# Epoch 150/200, Train Loss: 0.0548, Test Loss: 0.0591, Test Accuracy: 1.0000
# Epoch 151/200, Train Loss: 0.0546, Test Loss: 0.0591, Test Accuracy: 1.0000
# Epoch 152/200, Train Loss: 0.0542, Test Loss: 0.0584, Test Accuracy: 1.0000
# Epoch 153/200, Train Loss: 0.0540, Test Loss: 0.0577, Test Accuracy: 1.0000
# Epoch 154/200, Train Loss: 0.0538, Test Loss: 0.0574, Test Accuracy: 1.0000
# Epoch 155/200, Train Loss: 0.0536, Test Loss: 0.0570, Test Accuracy: 1.0000
# Epoch 156/200, Train Loss: 0.0532, Test Loss: 0.0568, Test Accuracy: 1.0000
# Epoch 157/200, Train Loss: 0.0529, Test Loss: 0.0565, Test Accuracy: 1.0000
# Epoch 158/200, Train Loss: 0.0527, Test Loss: 0.0563, Test Accuracy: 1.0000
# Epoch 159/200, Train Loss: 0.0523, Test Loss: 0.0558, Test Accuracy: 1.0000
# Epoch 160/200, Train Loss: 0.0521, Test Loss: 0.0555, Test Accuracy: 1.0000
# Epoch 161/200, Train Loss: 0.0519, Test Loss: 0.0549, Test Accuracy: 1.0000
# Epoch 162/200, Train Loss: 0.0519, Test Loss: 0.0547, Test Accuracy: 1.0000
# Epoch 163/200, Train Loss: 0.0514, Test Loss: 0.0552, Test Accuracy: 1.0000
# Epoch 164/200, Train Loss: 0.0506, Test Loss: 0.0549, Test Accuracy: 1.0000
# Epoch 165/200, Train Loss: 0.0503, Test Loss: 0.0548, Test Accuracy: 1.0000
# Epoch 166/200, Train Loss: 0.0500, Test Loss: 0.0539, Test Accuracy: 1.0000
# Epoch 167/200, Train Loss: 0.0499, Test Loss: 0.0538, Test Accuracy: 1.0000
# Epoch 168/200, Train Loss: 0.0495, Test Loss: 0.0537, Test Accuracy: 1.0000
# Epoch 169/200, Train Loss: 0.0492, Test Loss: 0.0534, Test Accuracy: 1.0000
# Epoch 170/200, Train Loss: 0.0489, Test Loss: 0.0535, Test Accuracy: 1.0000
# Epoch 171/200, Train Loss: 0.0486, Test Loss: 0.0528, Test Accuracy: 1.0000
# Epoch 172/200, Train Loss: 0.0484, Test Loss: 0.0533, Test Accuracy: 1.0000
# Epoch 173/200, Train Loss: 0.0480, Test Loss: 0.0529, Test Accuracy: 1.0000
# Epoch 174/200, Train Loss: 0.0477, Test Loss: 0.0522, Test Accuracy: 1.0000
# Epoch 175/200, Train Loss: 0.0475, Test Loss: 0.0526, Test Accuracy: 1.0000
# Epoch 176/200, Train Loss: 0.0472, Test Loss: 0.0526, Test Accuracy: 1.0000
# Epoch 177/200, Train Loss: 0.0469, Test Loss: 0.0523, Test Accuracy: 1.0000
# Epoch 178/200, Train Loss: 0.0467, Test Loss: 0.0512, Test Accuracy: 1.0000
# Epoch 179/200, Train Loss: 0.0465, Test Loss: 0.0512, Test Accuracy: 1.0000
# Epoch 180/200, Train Loss: 0.0462, Test Loss: 0.0504, Test Accuracy: 1.0000
# Epoch 181/200, Train Loss: 0.0461, Test Loss: 0.0506, Test Accuracy: 1.0000
# Epoch 182/200, Train Loss: 0.0457, Test Loss: 0.0506, Test Accuracy: 1.0000
# Epoch 183/200, Train Loss: 0.0455, Test Loss: 0.0510, Test Accuracy: 1.0000
# Epoch 184/200, Train Loss: 0.0453, Test Loss: 0.0517, Test Accuracy: 1.0000
# Epoch 185/200, Train Loss: 0.0451, Test Loss: 0.0517, Test Accuracy: 1.0000
# Epoch 186/200, Train Loss: 0.0450, Test Loss: 0.0518, Test Accuracy: 1.0000
# Epoch 187/200, Train Loss: 0.0448, Test Loss: 0.0508, Test Accuracy: 1.0000
# Epoch 188/200, Train Loss: 0.0444, Test Loss: 0.0508, Test Accuracy: 1.0000
# Epoch 189/200, Train Loss: 0.0442, Test Loss: 0.0505, Test Accuracy: 1.0000
# Epoch 190/200, Train Loss: 0.0440, Test Loss: 0.0502, Test Accuracy: 1.0000
# Epoch 191/200, Train Loss: 0.0438, Test Loss: 0.0492, Test Accuracy: 1.0000
# Epoch 192/200, Train Loss: 0.0435, Test Loss: 0.0499, Test Accuracy: 1.0000
# Epoch 193/200, Train Loss: 0.0434, Test Loss: 0.0502, Test Accuracy: 1.0000
# Epoch 194/200, Train Loss: 0.0433, Test Loss: 0.0494, Test Accuracy: 1.0000
# Epoch 195/200, Train Loss: 0.0429, Test Loss: 0.0487, Test Accuracy: 1.0000
# Epoch 196/200, Train Loss: 0.0427, Test Loss: 0.0470, Test Accuracy: 1.0000
# Epoch 197/200, Train Loss: 0.0424, Test Loss: 0.0476, Test Accuracy: 1.0000
# Epoch 198/200, Train Loss: 0.0421, Test Loss: 0.0478, Test Accuracy: 1.0000
# Epoch 199/200, Train Loss: 0.0419, Test Loss: 0.0473, Test Accuracy: 1.0000
# Epoch 200/200, Train Loss: 0.0418, Test Loss: 0.0475, Test Accuracy: 1.0000

# %%
# Vẽ biểu đồ loss và accuracy
# Vẽ biểu đồ loss và accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Test Accuracy Over Epochs')
plt.legend()

plt.show()
