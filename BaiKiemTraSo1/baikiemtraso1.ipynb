# %% [markdown]
# Nguyễn Hữu Trường - 207CT65867

# %% [markdown]
# cau 1

# %%
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah', 'Ivan', 'Jack', 'Kelly', 'Liam', 'Mona', 'Nina', 'Oscar'],
    'Age': [25, 30, 35, 28, 22, 45, 34, 31, 27, 29, 33, 40, 26, 32, 36],
    'Salary': [50000, 60000, 70000, 55000, 52000, 80000, 72000, 68000, 61000, 59000, 63000, 77000, 53000, 66000, 75000]
}
df = pd.DataFrame(data)

# %% [markdown]
# cau 2

# %%
print(df)
# Out:
#        Name  Age  Salary
# 0     Alice   25   50000
# 1       Bob   30   60000
# 2   Charlie   35   70000
# 3     David   28   55000
# 4       Eva   22   52000
# 5     Frank   45   80000
# 6     Grace   34   72000
# 7    Hannah   31   68000
# 8      Ivan   27   61000
# 9      Jack   29   59000
# 10    Kelly   33   63000
# 11     Liam   40   77000
# 12     Mona   26   53000
# 13     Nina   32   66000
# 14    Oscar   36   75000

# %% [markdown]
# cau 3

# %%
filtered_df = df[df['Age'] > 28]

# %%
print(filtered_df)
# Out:
#        Name  Age  Salary
# 1       Bob   30   60000
# 2   Charlie   35   70000
# 5     Frank   45   80000
# 6     Grace   34   72000
# 7    Hannah   31   68000
# 9      Jack   29   59000
# 10    Kelly   33   63000
# 11     Liam   40   77000
# 13     Nina   32   66000
# 14    Oscar   36   75000

# %% [markdown]
# cau 4

# %%
trungbinh_salary = df['Salary'].mean()

# %%
print("Trung binh cot Salary:",trungbinh_salary)
# Out:
# Trung binh cot Salary: 64066.666666666664

# %% [markdown]
# cau 5

# %%
nhomvatinhtong = df.groupby('Age')['Salary'].sum().reset_index()

# %%
print(nhomvatinhtong)
# Out:
#     Age  Salary
# 0    22   52000
# 1    25   50000
# 2    26   53000
# 3    27   61000
# 4    28   55000
# 5    29   59000
# 6    30   60000
# 7    31   68000
# 8    32   66000
# 9    33   63000
# 10   34   72000
# 11   35   70000
# 12   36   75000
# 13   40   77000
# 14   45   80000

# %% [markdown]
# cau 6

# %%
salarygiamdan = df.sort_values(by='Salary', ascending=False)

# %%
print(salarygiamdan)
# Out:
#        Name  Age  Salary
# 5     Frank   45   80000
# 11     Liam   40   77000
# 14    Oscar   36   75000
# 6     Grace   34   72000
# 2   Charlie   35   70000
# 7    Hannah   31   68000
# 13     Nina   32   66000
# 10    Kelly   33   63000
# 8      Ivan   27   61000
# 1       Bob   30   60000
# 9      Jack   29   59000
# 3     David   28   55000
# 12     Mona   26   53000
# 4       Eva   22   52000
# 0     Alice   25   50000

# %% [markdown]
# cau 7

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['Age'])
plt.xlabel('Name')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# cau 8

# %%
df.plot(x='Name', y='Salary', kind='line', marker='o', figsize=(10, 6), title='Biểu đồ đường')

plt.xlabel('Name')
plt.ylabel('Salary')

plt.show()

# %% [markdown]
# cau 9

# %%
import matplotlib.pyplot
plt.figure(figsize=(10,5))
plt.pie(df['Age'],labels=df["Name"])
plt.title("Biểu đồ tròn cột Age")
plt.show()

# %% [markdown]
# cau 10

# %%
df.plot.scatter(x='Age', y='Salary', figsize=(10, 6))
plt.title('Age vs Salary')
plt.show()

# %% [markdown]
# cau 11

# %%
check = df.isnull().any().any()

if check:
    print("DataFrame có chứa giá trị NaN.")
else:
    print("DataFrame không có giá trị NaN.")
# Out:
# DataFrame không có giá trị NaN.

# %% [markdown]
# cau 12

# %%
average_age = df['Age'].mean()
df.loc[df['Age'] > 30, 'Age'] = average_age

# %%
print(df)
# Out:
#        Name        Age  Salary
# 0     Alice  25.000000   50000
# 1       Bob  30.000000   60000
# 2   Charlie  29.284444   70000
# 3     David  28.000000   55000
# 4       Eva  22.000000   52000
# 5     Frank  29.284444   80000
# 6     Grace  29.284444   72000
# 7    Hannah  29.284444   68000
# 8      Ivan  27.000000   61000
# 9      Jack  29.000000   59000
# 10    Kelly  29.284444   63000
# 11     Liam  29.284444   77000
# 12     Mona  26.000000   53000
# 13     Nina  29.284444   66000
# 14    Oscar  29.284444   75000

# %% [markdown]
# cau 13

# %%
df['Age_normalized'] = (df['Age'] - df['Age'].min()) / (df['Age'].max() - df['Age'].min())

# %%
print(df[['Name', 'Age', 'Age_normalized']])
# Out:
#        Name        Age  Age_normalized
# 0     Alice  25.000000        0.375000
# 1       Bob  30.000000        1.000000
# 2   Charlie  29.284444        0.910556
# 3     David  28.000000        0.750000
# 4       Eva  22.000000        0.000000
# 5     Frank  29.284444        0.910556
# 6     Grace  29.284444        0.910556
# 7    Hannah  29.284444        0.910556
# 8      Ivan  27.000000        0.625000
# 9      Jack  29.000000        0.875000
# 10    Kelly  29.284444        0.910556
# 11     Liam  29.284444        0.910556
# 12     Mona  26.000000        0.500000
# 13     Nina  29.284444        0.910556
# 14    Oscar  29.284444        0.910556

# %% [markdown]
# cau 14

# %%
df['Age_group'] = 'Middle-aged'  
df.loc[df['Age'] < 30, 'Age_group'] = 'Young'
df.loc[df['Age'] > 60, 'Age_group'] = 'Old'

# %%
print(df[['Name', 'Age', 'Age_group']])
# Out:
#        Name        Age    Age_group
# 0     Alice  25.000000        Young
# 1       Bob  30.000000  Middle-aged
# 2   Charlie  29.284444        Young
# 3     David  28.000000        Young
# 4       Eva  22.000000        Young
# 5     Frank  29.284444        Young
# 6     Grace  29.284444        Young
# 7    Hannah  29.284444        Young
# 8      Ivan  27.000000        Young
# 9      Jack  29.000000        Young
# 10    Kelly  29.284444        Young
# 11     Liam  29.284444        Young
# 12     Mona  26.000000        Young
# 13     Nina  29.284444        Young
# 14    Oscar  29.284444        Young

# %% [markdown]
# cau 15

# %%
df['Salary_pct_change'] = df['Salary'].pct_change() * 100

# %%
print(df[['Name', 'Salary', 'Salary_pct_change']])
# Out:
#        Name  Salary  Salary_pct_change
# 0     Alice   50000                NaN
# 1       Bob   60000          20.000000
# 2   Charlie   70000          16.666667
# 3     David   55000         -21.428571
# 4       Eva   52000          -5.454545
# 5     Frank   80000          53.846154
# 6     Grace   72000         -10.000000
# 7    Hannah   68000          -5.555556
# 8      Ivan   61000         -10.294118
# 9      Jack   59000          -3.278689
# 10    Kelly   63000           6.779661
# 11     Liam   77000          22.222222
# 12     Mona   53000         -31.168831
# 13     Nina   66000          24.528302
# 14    Oscar   75000          13.636364

# %% [markdown]
# cau 16

# %%
df = df.drop_duplicates(subset=['Name'], keep='first')

# %%
print(df)
# Out:
#        Name        Age  Salary  Age_normalized    Age_group  Salary_pct_change
# 0     Alice  25.000000   50000        0.375000        Young                NaN
# 1       Bob  30.000000   60000        1.000000  Middle-aged          20.000000
# 2   Charlie  29.284444   70000        0.910556        Young          16.666667
# 3     David  28.000000   55000        0.750000        Young         -21.428571
# 4       Eva  22.000000   52000        0.000000        Young          -5.454545
# 5     Frank  29.284444   80000        0.910556        Young          53.846154
# 6     Grace  29.284444   72000        0.910556        Young         -10.000000
# 7    Hannah  29.284444   68000        0.910556        Young          -5.555556
# 8      Ivan  27.000000   61000        0.625000        Young         -10.294118
# 9      Jack  29.000000   59000        0.875000        Young          -3.278689
# 10    Kelly  29.284444   63000        0.910556        Young           6.779661
# ...

# %% [markdown]
# cau 17

# %%
df.to_csv("baikiemtraso1.csv", index=False)
